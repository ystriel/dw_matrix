# %%
# !pip install eli5
# Out:
# ...
#      |████████████████████████████████| 112kB 2.8MB/s
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score

import eli5
from eli5.sklearn import PermutationImportance

from ast import literal_eval
from tqdm import tqdm_notebook

# %%
cd "/content/drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  matrix_one/  README.md

# %%
ls data
# Out:
# men_shoes.csv

# %%
df = pd.read_csv('data/men_shoes.csv', low_memory = False)

# %%
def run_model(feats, model = DecisionTreeRegressor(max_depth = 5)):
    X = df[feats].values
    y = df['prices_amountmin'].values

    scores = cross_val_score(model, X, y, scoring = 'neg_mean_absolute_error')
    return np.mean(scores), np.std(scores)

# %%
df['brand_cat'] = df['brand'].factorize()[0]

# %%
run_model(['brand_cat'])
# Out:
# (-58.38655694633361, 4.223555478221712)

# %%
# Random Forest

# %%
model = RandomForestRegressor(max_depth = 5, n_estimators = 100, random_state = 0)
run_model(['brand_cat'], model)
# Out:
# (-57.47223572384038, 4.328288468270897)

# %%
# Zmiana nazw na małe litery
df['brand_cat'] = df['brand'].map(lambda x: str(x).lower()).factorize()[0]

# %%
model = RandomForestRegressor(max_depth = 5, n_estimators = 100, random_state = 0)
run_model(['brand_cat'], model)
# Out:
# (-57.31783843165656, 4.181246596160967)

# %%
df.head()
# Out:
#                      id asins  ... weight brand_cat
# 0  AVpfHrJ6ilAPnD_xVXOI   NaN  ...    NaN         0
# 1  AVpfHrJ6ilAPnD_xVXOI   NaN  ...    NaN         0
# 2  AVpfHsWP1cnluZ0-eVZ7   NaN  ...    NaN         1
# 3  AVpfHsWP1cnluZ0-eVZ7   NaN  ...    NaN         1
# 4  AVpfHsWP1cnluZ0-eVZ7   NaN  ...    NaN         1
#
# [5 rows x 49 columns]

# %%
df.features
# Out:
# 0        [{"key":"Gender","value":["Men"]},{"key":"Shoe...
# 1        [{"key":"Gender","value":["Men"]},{"key":"Shoe...
# 2        [{"key":"Gender","value":["Men"]},{"key":"Colo...
# 3        [{"key":"Gender","value":["Men"]},{"key":"Colo...
# 4        [{"key":"Gender","value":["Men"]},{"key":"Colo...
#                                ...
# 18275    [{"key":"Style","value":["Desert Boots"]},{"ke...
# 18276    [{"key":"Shoe Size","value":["9.5"]},{"key":"G...
# 18277    [{"key":"Gender","value":["Unisex"]},{"key":"F...
# 18278    [{"key":"Gender","value":["Unisex"]},{"key":"F...
# 18279    [{"key":"Gender","value":["Unisex"]},{"key":"F...
# Name: features, Length: 18280, dtype: object

# %%
df.features.head().values
# Out:
# array(['[{"key":"Gender","value":["Men"]},{"key":"Shoe Size","value":["M"]},{"key":"Shoe Category","value":["Men\'s Shoes"]},{"key":"Color","value":["Multicolor"]},{"key":"Manufacturer Part Number","value":["8190-W-NAVY-7.5"]},{"key":"Brand","value":["Josmo"]}]',
#        '[{"key":"Gender","value":["Men"]},{"key":"Shoe Size","value":["M"]},{"key":"Shoe Category","value":["Men\'s Shoes"]},{"key":"Color","value":["Multicolor"]},{"key":"Manufacturer Part Number","value":["8190-W-NAVY-7.5"]},{"key":"Brand","value":["Josmo"]}]',
#        '[{"key":"Gender","value":["Men"]},{"key":"Color","value":["Black"]},{"key":"Shipping Weight (in pounds)","value":["0.45"]},{"key":"Condition","value":["New"]},{"key":"Brand","value":["SERVUS BY HONEYWELL"]},{"key":"manufacturer_part_number","value":["ZSR101BLMLG"]}]',
# ...

# %%
test = {'key' : 'value'}
test['key']
# Out:
# 'value'

# %%
str(test)
# Out:
# "{'key': 'value'}"

# %%
# Chcemy przywrócić ten string do postaci słownika

# %%
string_dict = '[{"key":"Gender","value":["Men"]},{"key":"Shoe Size","value":["M"]},{"key":"Shoe Category","value":["Men\'s Shoes"]},{"key":"Color","value":["Multicolor"]},{"key":"Manufacturer Part Number","value":["8190-W-NAVY-7.5"]},{"key":"Brand","value":["Josmo"]}]'
literal_eval(string_dict)
# Out:
# [{'key': 'Gender', 'value': ['Men']},
#  {'key': 'Shoe Size', 'value': ['M']},
#  {'key': 'Shoe Category', 'value': ["Men's Shoes"]},
#  {'key': 'Color', 'value': ['Multicolor']},
#  {'key': 'Manufacturer Part Number', 'value': ['8190-W-NAVY-7.5']},
#  {'key': 'Brand', 'value': ['Josmo']}]

# %%
literal_eval(string_dict)[0]['key']
# Out:
# 'Gender'

# %%
literal_eval(string_dict)[0]['value'][0]
# Out:
# 'Men'

# %%
def parse_features(x):
    if str(x) == 'nan': return []
    return literal_eval(x.replace('\\"', '"'))

df['features_parsed'] = df['features'].map(parse_features)

# %%
df['features_parsed'].head().values
# Out:
# array([list([{'key': 'Gender', 'value': ['Men']}, {'key': 'Shoe Size', 'value': ['M']}, {'key': 'Shoe Category', 'value': ["Men's Shoes"]}, {'key': 'Color', 'value': ['Multicolor']}, {'key': 'Manufacturer Part Number', 'value': ['8190-W-NAVY-7.5']}, {'key': 'Brand', 'value': ['Josmo']}]),
#        list([{'key': 'Gender', 'value': ['Men']}, {'key': 'Shoe Size', 'value': ['M']}, {'key': 'Shoe Category', 'value': ["Men's Shoes"]}, {'key': 'Color', 'value': ['Multicolor']}, {'key': 'Manufacturer Part Number', 'value': ['8190-W-NAVY-7.5']}, {'key': 'Brand', 'value': ['Josmo']}]),
#        list([{'key': 'Gender', 'value': ['Men']}, {'key': 'Color', 'value': ['Black']}, {'key': 'Shipping Weight (in pounds)', 'value': ['0.45']}, {'key': 'Condition', 'value': ['New']}, {'key': 'Brand', 'value': ['SERVUS BY HONEYWELL']}, {'key': 'manufacturer_part_number', 'value': ['ZSR101BLMLG']}]),
# ...

# %%
def parse_features(x):
    output_dict = {}
    if str(x) == 'nan': return output_dict

    features = literal_eval(x.replace('\\"', '"'))
    for item in features:
      key = item['key'].lower().strip()
      value = item['value'][0].lower().strip()

      output_dict[key] = value

    return output_dict

# %%
df['features_parsed'] = df['features'].map(parse_features)

# %%
df['features_parsed'].head().values
# Out:
# array([{'gender': 'men', 'shoe size': 'm', 'shoe category': "men's shoes", 'color': 'multicolor', 'manufacturer part number': '8190-w-navy-7.5', 'brand': 'josmo'},
#        {'gender': 'men', 'shoe size': 'm', 'shoe category': "men's shoes", 'color': 'multicolor', 'manufacturer part number': '8190-w-navy-7.5', 'brand': 'josmo'},
#        {'gender': 'men', 'color': 'black', 'shipping weight (in pounds)': '0.45', 'condition': 'new', 'brand': 'servus by honeywell', 'manufacturer_part_number': 'zsr101blmlg'},
#        {'gender': 'men', 'color': 'black', 'shipping weight (in pounds)': '0.45', 'condition': 'new', 'brand': 'servus by honeywell', 'manufacturer_part_number': 'zsr101blmlg'},
#        {'gender': 'men', 'color': 'black', 'shipping weight (in pounds)': '0.45', 'condition': 'new', 'brand': 'servus by honeywell', 'manufacturer_part_number': 'zsr101blmlg'}],
#       dtype=object)

# %%
keys = set() # zbiór trzymający tylko unikalne wartości
df['features_parsed'].map(lambda x: keys.update(x.keys()))
len(keys)
# Out:
# 476

# %%
def get_name_feat(key):
  return 'feat_' + key

for key in tqdm_notebook(keys):
  df[get_name_feat(key)] = df.features_parsed.map(lambda feats: feats[key] if key in feats else np.nan)

# %%
#for key in tqdm_notebook(keys):
#  print(key)
  # break
# Out:
# ...
# band length (in.)
# shape
# metal type
# product in inches (l x w x h)
# sleeve length
# motion control
# shoe fastening type
# lens material
# diamond color
# bridge width
# ground
# dial color
# frame material
# width
# box
# multi pack indicator
# front style
# reinforced pockets
# adidas
# cm
# assembled product weight
# necklace type
# what includes
# heart rate monitor
# date first available
# sub style
# euro size
# band width
# movement
# main color
# character
# stylenumber
# hooded
# jewelry setting
# shoe height
# charge time (minutes)
# used with equipment type
# band color
# audience
# size/dimensions
# manufacturer number
# product type
# has expiration
# fabrication
# product id
# picture
# product name
# year
# mechanic
# battery voltage
# navy blue
# pattern
# alarm
# mpn
# use
# stone type
# auto shut-off
# origin of components
# disclosures
# international shipping
# removable liner
# number of compartments
# wheel type
# shipping to usa
# genre
# profession
# ...

# %%
df.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'count', 'dateadded',
#        'dateupdated', 'descriptions', 'dimension',
#        ...
#        'feat_lens tint', 'feat_hardsided or softsided', 'feat_isbn',
#        'feat_features & fastening', 'feat_power reserve',
#        'feat_country of origin', 'feat_fabric care instructions',
#        'feat_expandable', 'feat_thick, warm, cozy', 'feat_has paper wood'],
#       dtype='object', length=526)

# %%
df[df['feat_athlete'].isnull()].shape
# Out:
# (18272, 526)

# %%
df.shape[0]
# Out:
# 18280

# %%
df[False == df['feat_athlete'].isnull()].shape[0] # Tylko 8 przypadków gdy jest ten atrybut
# Out:
# 8

# %%
df[False == df['feat_athlete'].isnull()].shape[0] / df.shape[0] * 100 # Czyli 0.04 % przypadków
# Out:
# 0.0437636761487965

# %%
keys_stat = {}

for key in keys:
  keys_stat[key] = df[False == df[get_name_feat(key)].isnull()].shape[0] / df.shape[0] * 100

# %%
keys_stat
# Out:
# {'100% adidas authentic': 0.005470459518599562,
#  'accessory type': 0.1422319474835886,
#  'adidas': 0.005470459518599562,
#  'adjustable': 0.34463894967177244,
#  'age': 0.6400437636761488,
#  'age end': 0.4431072210065646,
#  'age gender group': 0.12582056892778995,
#  'age group': 27.64770240700219,
#  'age range': 0.5470459518599562,
#  'age segment': 0.1422319474835886,
#  'age start': 0.4431072210065646,
#  'airport friendly': 0.005470459518599562,
#  'alarm': 0.23522975929978115,
#  'amazonbestsellersrank': 0.06017505470459519,
#  'animal type': 0.005470459518599562,
#  'antiscratch lens coating': 0.005470459518599562,
#  'applicable': 0.02188183807439825,
#  'arm': 0.6236323851203501,
#  'article': 0.005470459518599562,
#  'assembled in country of origin': 2.199124726477024,
#  'assembled product dimensions (l x w x h)': 10.300875273522976,
#  'assembled product weight': 1.5536105032822756,
#  'athlete': 0.0437636761487965,
#  'atpv arc rating': 0.005470459518599562,
# ...

# %%
{k : v for k, v in keys_stat.items() if v > 30}
# Out:
# {'brand': 48.62691466083151,
#  'color': 47.784463894967175,
#  'gender': 50.17505470459519,
#  'manufacturer part number': 36.252735229759296,
#  'material': 34.9070021881838}

# %%
df['feat_brand_cat'] = df['feat_brand'].factorize()[0]
df['feat_color_cat'] = df['feat_color'].factorize()[0]
df['feat_gender_cat'] = df['feat_gender'].factorize()[0]
df['feat_manufacturer part number_cat'] = df['feat_manufacturer part number'].factorize()[0]
df['feat_material_cat'] = df['feat_material'].factorize()[0]

# %%
# Sprawdzanie czy się pokrywa z brand
df[df.brand != df.feat_brand].shape
# Out:
# (18228, 531)

# %%
df[df.brand == df.feat_brand][['brand', 'feat_brand']].head()
# Out:
#        brand feat_brand
# 2163  adidas     adidas
# 2417  adidas     adidas
# 3021  adidas     adidas
# 3054  adidas     adidas
# 3629   totes      totes

# %%
df[df.brand != df.feat_brand][['brand', 'feat_brand']].head()
# Out:
#                  brand           feat_brand
# 0                Josmo                josmo
# 1                Josmo                josmo
# 2  SERVUS BY HONEYWELL  servus by honeywell
# 3  SERVUS BY HONEYWELL  servus by honeywell
# 4  SERVUS BY HONEYWELL  servus by honeywell

# %%
df['brand'] = df['brand'].map(lambda x: str(x).lower())
df[df.brand != df.feat_brand][['brand', 'feat_brand']].head()
# Out:
#                brand feat_brand
# 21            rubies    generic
# 22            rubies    generic
# 23            rubies    generic
# 24         unbranded        NaN
# 31  american fighter        NaN

# %%
df[df.brand == df.feat_brand].shape[0]
# Out:
# 8846

# %%
model = RandomForestRegressor(max_depth = 5, n_estimators = 100)
run_model(['brand_cat'], model)
# Out:
# (-57.24186526259291, 4.220071240662979)

# %%
feats = ['brand_cat', 'feat_color_cat', 'feat_gender_cat', 'feat_material_cat', 'feat_manufacturer part number_cat']
run_model(feats, model)
# Out:
# (-57.362686705831514, 4.27207042899782)

# %%
X = df[feats].values
y = df['prices_amountmin'].values

m = RandomForestRegressor(max_depth = 5, n_estimators = 100, random_state = 0)
m.fit(X, y)

perm = PermutationImportance(m, random_state = 1).fit(X, y);
eli5.show_weights(perm, feature_names = feats)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2645
#
#                     &plusmn; 0.0096
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 brand_cat
#             </td>
# ...

# %%
# Widać które cechy wyglądają na najmocniejsze

feats = ['brand_cat', 'feat_gender_cat', 'feat_material_cat']
run_model(feats, model)
# Out:
# (-57.13237224428002, 4.153728631243851)

# %%
# Warto lepiej przyjrzeć się brand, bo to ważna cecha
df['brand'].value_counts()
# Out:
# nike                    1777
# puma                     609
# ralph lauren             526
# vans                     386
# new balance              371
#                         ...
# aristocrat homewares       1
# pleaser shoes              1
# party favors plus          1
# unbrand                    1
# aiden                      1
# Name: brand, Length: 1732, dtype: int64

# %%
df['brand'].value_counts(normalize = True) # 10% obuwia jest nike
# Out:
# nike                    0.097210
# puma                    0.033315
# ralph lauren            0.028775
# vans                    0.021116
# new balance             0.020295
#                           ...
# aristocrat homewares    0.000055
# pleaser shoes           0.000055
# party favors plus       0.000055
# unbrand                 0.000055
# aiden                   0.000055
# Name: brand, Length: 1732, dtype: float64

# %%
df[df['brand'] == 'nike'].features_parsed.head().values
# Out:
# array([{'sport': 'soccer', 'main color': 'orange', 'type': 'cleats', 'condition': 'new without box'},
#        {'sport': 'soccer', 'main color': 'orange', 'type': 'cleats', 'condition': 'new without box'},
#        {'sport': 'soccer', 'main color': 'orange', 'type': 'cleats', 'condition': 'new without box'},
#        {'style': 'athletic sneakers', 'condition': 'new with box'}, {}],
#       dtype=object)

# %%
# 2 nowe cechy
df['feat_sport_cat'] = df['feat_sport'].factorize()[0]
df['feat_style_cat'] = df['feat_style'].factorize()[0]

# %%
feats = ['brand_cat', 'feat_gender_cat', 'feat_material_cat', 'feat_style_cat', 'feat_sport_cat']
run_model(feats, model)
# Out:
# (-57.09920584457318, 4.254746865990005)

# %%
df[df['brand'] == 'nike'].features_parsed.sample(5).values
# Out:
# array([{'style': 'athletic sneakers', 'condition': 'new with box'},
#        {'type': 'cleats', 'condition': 'new with box'},
#        {'sport': 'baseball & softball', 'condition': 'new without box', 'type': 'cleats'},
#        {'sport': 'soccer', 'condition': 'new with box', 'type': 'cleats'},
#        {'style': 'skateboarding', 'authenticity': '100% authentic guaranteed', 'material': 'suede', 'country/region of manufacture': 'vietnam', 'condition': 'new with box', 'mpn': '839685416'}],
#       dtype=object)

# %%
df['feat_age group'].value_counts()
# Out:
# adult               4563
# men                  350
# child                 77
# men's                 33
# unisex                 6
# toddler                4
# mens                   4
# infant                 4
# boys'                  3
# men||women             2
# women                  2
# women ,�� unisex       2
# youth                  2
# adult ,�� teen         1
# 12 up                  1
# Name: feat_age group, dtype: int64

# %%
for key in keys:
  df[get_name_feat(key) + '_cat'] = df[get_name_feat(key)].factorize()[0]

# %%
feats_cat = [x for x in df.columns if 'cat' in x]

# %%
feats += feats_cat

# %%
feats = set(feats) # żeby było unikalne

# %%
feats
# Out:
# {'brand_cat',
#  'categories',
#  'feat_100% adidas authentic_cat',
#  'feat_accessory type_cat',
#  'feat_adidas_cat',
#  'feat_adjustable_cat',
#  'feat_age end_cat',
#  'feat_age gender group_cat',
#  'feat_age group_cat',
#  'feat_age range_cat',
#  'feat_age segment_cat',
#  'feat_age start_cat',
#  'feat_age_cat',
#  'feat_airport friendly_cat',
#  'feat_alarm_cat',
#  'feat_amazonbestsellersrank_cat',
#  'feat_animal type_cat',
#  'feat_antiscratch lens coating_cat',
#  'feat_applicable_cat',
#  'feat_arm_cat',
#  'feat_article_cat',
#  'feat_assembled in country of origin_cat',
#  'feat_assembled product dimensions (l x w x h)_cat',
#  'feat_assembled product weight_cat',
#  'feat_athlete_cat',
#  'feat_atpv arc rating_cat',
#  'feat_attachment_cat',
#  'feat_audience_cat',
#  'feat_authenticity_cat',
#  'feat_auto shut-off_cat',
#  'feat_auto_cat',
#  'feat_autographed_cat',
#  'feat_bag size range_cat',
#  'feat_band color_cat',
#  'feat_band length (in.)_cat',
# ...

# %%
feats = ['brand_cat', 'feat_metal type_cat', 'feat_shape_cat', 'feat_brand_cat']

run_model(feats, model)
# Out:
# (-57.923254230484304, 4.231086272339001)

# %%
feats
# Out:
# ['brand_cat', 'categories']

# %%
df['weight'].unique()
# Out:
# array([nan, '3.0 lbs', '9 g', '1.45 lbs', '0.45 lbs', '1.0 lbs',
#        '0.23 lbs', '5.0 lbs', '5.5 lbs', '7.45 lbs', '4.0 lbs',
#        '2.7969 lbs', '3.9 lbs', '4.6 pounds', '2.1 lbs', '1.1057 lbs',
#        '15.0 lbs', '2.4 ounces', '454 g', '0.105 lbs', '9.1 ounces',
#        '4.8 lbs', '6.1 lbs', '6.5 lbs', '1.1041 lbs', '1.3 Kg', '91 g',
#        '20.0 lbs', '6.0 lbs', '386 g', '0.81 lbs', '4.5 lbs',
#        '0.5 ounces', '2.0 lbs', '3.13 lbs', '5.9 lbs', '6.15 lbs',
#        '1 pounds', '1.95 lbs', '2.15 lbs', '2 pounds', '2.1 pounds',
#        '14 Kg', '0.4788 lbs', '10.0 lbs', '0.38 lbs', '2.5 lbs',
#        '68.912 lbs', '45 g', '13.09 lbs', '2.5 pounds', '0.21 lbs',
#        '16.75 lbs', '6.3 lbs', '272 g', '1.8 Kg', '2.8 pounds', '0.1 lbs',
#        '5.05 lbs', '0.28 lbs', '76.08 lbs', '0.15 lbs', '200 g',
#        '7.8 pounds', '399 g', '4.95 lbs', '64.144 lbs', '24 pounds',
#        '73.696 lbs', '1.6 lbs', '6.6 ounces', '5 g', '1.2 Kg', '862 g',
# ...

# %%
# można przerobić każdą wagę np. do gramów (lbs, g, kg, Kg, ounces)

# %%
feats = ['brand_cat', 'feat_material_cat', 'feat_gender_cat', 'feat_adjustable_cat', 'feat_metal type_cat', 'feat_shape_cat', 'feat_brand_cat']

# %%
model = RandomForestRegressor(max_depth = 5, n_estimators = 100)
result = run_model(feats, model)

# %%
X = df[feats].values
y = df['prices_amountmin'].values

m = RandomForestRegressor(max_depth = 5, n_estimators = 100, random_state = 0)
m.fit(X, y)

print(result)
perm = PermutationImportance(m, random_state = 1).fit(X, y);
eli5.show_weights(perm, feature_names = feats)
# Out:
# (-57.36232563280695, 4.054170302749067)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2584
#
#                     &plusmn; 0.0100
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
# ...

# %%
# !git add matrix_one/day5.ipynb
# Out:
# fatal: pathspec 'matrix_one/day5.ipynb' did not match any files

# %%
ls
# Out:
# data/  HelloGithub.ipynb  LICENSE  matrix_one/  README.md

# %%
ls matrix_one
# Out:
# day3.ipynb
